# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import linregress
from statistics import mean, median
from math import isfinite

# ignore 'nan' values rather than throw a Runtime warning
np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
df = pd.read_csv('data-final.csv')
# 28k single points across ~700 molecules and a lot of methods

# %%
df.columns
# Out:
# Index(['name', 'geom', 'natoms', 'dlpno', 'mp2', 'wb97', 'b973c', 'pbe',
#        'pbeSVP', 'pbeh3c', 'b3lypTZ', 'b3lypSVP', 'gfn0', 'gfn1', 'gfn2',
#        'pm7E', 'pm7HOF', 'mmff', 'mmffNew', 'uff', 'gaff', 'ani1x', 'ani1cc',
#        'ani2'],
#       dtype='object')

# %%
df.dtypes # make sure the numbers are all float64
# Out:
# name         object
# geom         object
# natoms        int64
# dlpno       float64
# mp2         float64
# wb97        float64
# b973c       float64
# pbe         float64
# pbeSVP      float64
# pbeh3c      float64
# b3lypTZ     float64
# b3lypSVP    float64
# gfn0        float64
# gfn1        float64
# gfn2        float64
# pm7E        float64
# pm7HOF      float64
# mmff        float64
# mmffNew     float64
# uff         float64
# gaff        float64
# ani1x       float64
# ani1cc      float64
# ani2        float64
# dtype: object

# %%
# this list allows you to pick only a subset for analysis
methods = ['mmff', 'uff', 'gaff', 'pm7HOF', 'ani1x', 'ani1cc', 'ani2', 'gfn0', 'gfn1', 'gfn2', 'pbe', 'pbeSVP', 'pbeh3c', 'b3lypTZ', 'b3lypSVP', 'wb97', 'mp2', 'dlpno']

# %%
names = np.unique(df['name']) # all the molecule names
print(names)
# Out:
# ['astex_1g9v' 'astex_1gkc' 'astex_1gm8' 'astex_1hnn' 'astex_1hp0'
#  'astex_1hq2' 'astex_1hvy' 'astex_1hwi' 'astex_1ia1' 'astex_1ig3'
#  'astex_1j3j' 'astex_1jd0' 'astex_1jje' 'astex_1jla' 'astex_1k3u'
#  'astex_1ke5' 'astex_1kzk' 'astex_1l2s' 'astex_1l7f' 'astex_1lpz'
#  'astex_1lrh' 'astex_1m2z' 'astex_1meh' 'astex_1mmv' 'astex_1mzc'
#  'astex_1n1m' 'astex_1n2j' 'astex_1n2v' 'astex_1n46' 'astex_1nav'
#  'astex_1of1' 'astex_1of6' 'astex_1opk' 'astex_1oq5' 'astex_1owe'
#  'astex_1oyt' 'astex_1p2y' 'astex_1p62' 'astex_1pmn' 'astex_1q1g'
#  'astex_1q41' 'astex_1q4g' 'astex_1r1h' 'astex_1r55' 'astex_1r58'
#  'astex_1r9o' 'astex_1s3v' 'astex_1sg0' 'astex_1sj0' 'astex_1sq5'
#  'astex_1t40' 'astex_1t46' 'astex_1t9b' 'astex_1tow' 'astex_1tt1'
#  'astex_1tz8' 'astex_1u1c' 'astex_1u4d' 'astex_1uml' 'astex_1unl'
#  'astex_1uou' 'astex_1v0p' 'astex_1v48' 'astex_1v4s' 'astex_1vcj'
#  'astex_1w1p' 'astex_1w2g' 'astex_1xm6' 'astex_1xoq' 'astex_1xoz'
#  'astex_1y6b' 'astex_1ygc' 'astex_1yqy' 'astex_1yvf' 'astex_1ywr'
#  'astex_1z95' 'astex_2bm2' 'astex_2br1' 'astex_2bsm' 'omegacsd_ABHYTZ'
#  'omegacsd_ABIMAZ' 'omegacsd_ABSBPP' 'omegacsd_ABVPRO' 'omegacsd_ABXBPC'
#  'omegacsd_ABZNPS' 'omegacsd_ACENHT' 'omegacsd_ACPIXZ' 'omegacsd_ACTHBZ'
#  'omegacsd_ADPRTR' 'omegacsd_AMOCMS10' 'omegacsd_AMPDAM' 'omegacsd_ANOPPS'
#  'omegacsd_ANTZOA' 'omegacsd_ANTZOB' 'omegacsd_AOPCHY' 'omegacsd_APRTAM'
#  'omegacsd_AURMIN' 'omegacsd_AZLNPR' 'omegacsd_BAFJEX10' 'omegacsd_BAFREF'
#  'omegacsd_BAFYOW' 'omegacsd_BAJZOB10' 'omegacsd_BATROD' 'omegacsd_BATXID'
#  'omegacsd_BAXOZO' 'omegacsd_BBSPRT10' 'omegacsd_BEDLUR'
#  'omegacsd_BEHHOL10' 'omegacsd_BEKDIE' 'omegacsd_BELWOE' 'omegacsd_BENPRL'
#  'omegacsd_BESCEH' 'omegacsd_BETFAH' 'omegacsd_BEWLIY10'
#  'omegacsd_BEWLOE10' 'omegacsd_BEXVOP' 'omegacsd_BHMPET' 'omegacsd_BIBHID'
#  'omegacsd_BIBSEK' 'omegacsd_BSBTHP' 'omegacsd_BTHYDX' 'omegacsd_BUDCUY'
#  'omegacsd_BUFXOP' 'omegacsd_BUHNIB' 'omegacsd_BUNFUL' 'omegacsd_BUSNIM'
#  'omegacsd_BUTDID' 'omegacsd_BUVYIA' 'omegacsd_BUYZIE' 'omegacsd_BZAPCX10'
#  'omegacsd_BZAPUC20' 'omegacsd_CABCUD' 'omegacsd_CAFGIZ' 'omegacsd_CAGXEN'
#  'omegacsd_CALLEG' 'omegacsd_CANPUC' 'omegacsd_CARNID' 'omegacsd_CATXIE'
#  'omegacsd_CAVNUI' 'omegacsd_CBMHZP' 'omegacsd_CBSTHP' 'omegacsd_CBZHYX'
#  'omegacsd_CDBMPI10' 'omegacsd_CEJTIU' 'omegacsd_CEKNOV' 'omegacsd_CELDEC'
#  'omegacsd_CELXOG' 'omegacsd_CENNIS' 'omegacsd_CETZOQ' 'omegacsd_CEVTUS'
#  'omegacsd_CEWFUF' 'omegacsd_CFBPBI' 'omegacsd_CIBPEI' 'omegacsd_CIBPOS'
#  'omegacsd_CIDSIR' 'omegacsd_CIHFAA' 'omegacsd_CIHJAE' 'omegacsd_CIJFEG'
#  'omegacsd_CIJVAS' 'omegacsd_CIPXEE' 'omegacsd_CIXFIY' 'omegacsd_CIXTOS'
#  'omegacsd_CLPHAC' 'omegacsd_CLPNXA' 'omegacsd_CLPSAM' 'omegacsd_CLPTBU'
#  'omegacsd_CMANPQ' 'omegacsd_CMAPTX' 'omegacsd_CMPEPI' 'omegacsd_CMSMOC'
#  'omegacsd_CMXPMB' 'omegacsd_CMXPYO' 'omegacsd_CNBPCT' 'omegacsd_CNINDO'
#  'omegacsd_COCHOL' 'omegacsd_CODYUP10' 'omegacsd_COFHIO10'
#  'omegacsd_COKBOT' 'omegacsd_COKSUQ' 'omegacsd_COKTAX' 'omegacsd_COTXUE'
#  'omegacsd_COVXIU' 'omegacsd_COYHUT10' 'omegacsd_COYPIP' 'omegacsd_COYTOZ'
#  'omegacsd_COYVIV' 'omegacsd_COZFOM' 'omegacsd_CPIPLA' 'omegacsd_CPPHAM'
#  'omegacsd_CPQZOL' 'omegacsd_CPYPTZ' 'omegacsd_CUHNEY10' 'omegacsd_CUJSAB'
#  'omegacsd_CUNTIO' 'omegacsd_CUSLUX' 'omegacsd_CUWRIV' 'omegacsd_CYCLIZ10'
#  'omegacsd_DABGUI' 'omegacsd_DADDUH' 'omegacsd_DAFTOT' 'omegacsd_DAFVUB'
#  'omegacsd_DAHNIJ' 'omegacsd_DAKGEB' 'omegacsd_DANNEL' 'omegacsd_DAWRAU'
#  'omegacsd_DAXKAO' 'omegacsd_DCLPET' 'omegacsd_DCTXAN' 'omegacsd_DEBBER'
#  'omegacsd_DEBBOB' 'omegacsd_DEBFAR' 'omegacsd_DECZIU' 'omegacsd_DENBUT'
#  'omegacsd_DENDAC' 'omegacsd_DERZAB' 'omegacsd_DIAVER' 'omegacsd_DIGSIV'
#  'omegacsd_DIPJAN10' 'omegacsd_DISHOC' 'omegacsd_DIWPUU' 'omegacsd_DIWWUB'
#  'omegacsd_DIZREJ' 'omegacsd_DIZWAK' 'omegacsd_DOHREX' 'omegacsd_DOLJIX'
#  'omegacsd_DOPXIP' 'omegacsd_DOTFEX' 'omegacsd_DOXANN' 'omegacsd_DUDNUL'
#  'omegacsd_DUDPAT' 'omegacsd_DUHSUU' 'omegacsd_DUMTAG' 'omegacsd_DUPKII'
#  'omegacsd_DUXYOK' 'omegacsd_DUZDAD' 'omegacsd_DUZRAR' 'omegacsd_EBTNIC'
#  'omegacsd_ECBHMP' 'omegacsd_EHMPYX10' 'omegacsd_EITDZL' 'omegacsd_EMZPPO'
#  'omegacsd_EPCMPO' 'omegacsd_EXOADN' 'omegacsd_FABSOQ10'
#  'omegacsd_FABWUA10' 'omegacsd_FACCER10' 'omegacsd_FAGHIE'
#  'omegacsd_FAHTUD' 'omegacsd_FAHXIV' 'omegacsd_FAJVAN' 'omegacsd_FANPUF'
#  'omegacsd_FANRER' 'omegacsd_FAVYEG' 'omegacsd_FAWREA' 'omegacsd_FAXPUP'
#  'omegacsd_FBPAZD' 'omegacsd_FECPUY' 'omegacsd_FEFPOV' 'omegacsd_FEKYEZ'
#  'omegacsd_FEMMAL' 'omegacsd_FEVZUB' 'omegacsd_FEWBAK' 'omegacsd_FEYJEY'
#  'omegacsd_FEYKUP' 'omegacsd_FHFPBY' 'omegacsd_FIBREN' 'omegacsd_FIJJUD'
#  'omegacsd_FIVPUV' 'omegacsd_FIWLUS' 'omegacsd_FIXNUV' 'omegacsd_FLPNTX10'
#  'omegacsd_FOBZIF' 'omegacsd_FOGWAZ' 'omegacsd_FOJZUZ' 'omegacsd_FOLMEY'
#  'omegacsd_FOLYIO' 'omegacsd_FOMDUG' 'omegacsd_FOPMIG' 'omegacsd_FOWPOW'
#  'omegacsd_FOYLIO' 'omegacsd_FPAMCA' 'omegacsd_FUCFIS' 'omegacsd_FUDVUV'
#  'omegacsd_FUGSIJ' 'omegacsd_FUHHAR' 'omegacsd_FUHLID' 'omegacsd_FUJRUX'
#  'omegacsd_FUMBOE' 'omegacsd_FUNXUH' 'omegacsd_FUNYAO' 'omegacsd_FUPFIF'
#  'omegacsd_FURACM' 'omegacsd_FURKEI' 'omegacsd_FURSEM01' 'omegacsd_FUSZOI'
#  'omegacsd_GAKWIY' 'omegacsd_GALMOV' 'omegacsd_GALSEM' 'omegacsd_GANFIK'
#  'omegacsd_GASPUL' 'omegacsd_GASXED' 'omegacsd_GATPOG' 'omegacsd_GAVMIZ'
#  'omegacsd_GEBJOM' 'omegacsd_GEHKIN' 'omegacsd_GEJJUA' 'omegacsd_GEJLAI'
#  'omegacsd_GEKWAU' 'omegacsd_GIFZAW' 'omegacsd_GIHKAJ' 'omegacsd_GIHTUM'
#  'omegacsd_GIHWUP' 'omegacsd_GIKJOZ' 'omegacsd_GINKUJ' 'omegacsd_HADLAZ'
#  'omegacsd_HALDOL' 'omegacsd_HALJOT' 'omegacsd_HALOPE' 'omegacsd_HALSES'
#  'omegacsd_HASCOT' 'omegacsd_HATKES' 'omegacsd_HAVJET' 'omegacsd_HAVLUL'
#  'omegacsd_HAVRUR' 'omegacsd_HBFRAN' 'omegacsd_HECHEC' 'omegacsd_HEHVOF'
#  'omegacsd_HEJTAR' 'omegacsd_HEKROE' 'omegacsd_HEKZAY' 'omegacsd_HEMLOA'
#  'omegacsd_HEMWUR' 'omegacsd_HEMXIG' 'omegacsd_HEPGAK' 'omegacsd_HEPKUI'
#  'omegacsd_HEPYAC' 'omegacsd_HEVJAT' 'omegacsd_HEVRIJ' 'omegacsd_HEVXEL'
#  'omegacsd_HEXFEV' 'omegacsd_HEXYIS' 'omegacsd_JOTDAX' 'omegacsd_JOXFIL'
#  'omegacsd_JUBGES' 'omegacsd_JUBJOF' 'omegacsd_JUDLUP' 'omegacsd_JUDWEK'
#  'omegacsd_JUHHEZ' 'omegacsd_JUKZUK' 'omegacsd_JUVPAR' 'omegacsd_KABJOM'
#  'omegacsd_KACKII' 'omegacsd_KAVLIC' 'omegacsd_KAVNOK' 'omegacsd_KAXXAI'
#  'omegacsd_KEBVES' 'omegacsd_KECDUR' 'omegacsd_KEJBEG' 'omegacsd_KEJGEL'
#  'omegacsd_KEMHOZ' 'omegacsd_KICRIX' 'omegacsd_KIFZAA' 'omegacsd_KIHWAZ'
#  'omegacsd_KIHWED' 'omegacsd_KINJIA' 'omegacsd_KIXLOS' 'omegacsd_KOFKUL'
#  'omegacsd_KOFLIA' 'omegacsd_KOFLOG' 'omegacsd_KOFMIB' 'omegacsd_KOJMEB'
#  'omegacsd_KOKBIV' 'omegacsd_KOTGIJ' 'omegacsd_KUBHEU' 'omegacsd_KUFPIK'
#  'omegacsd_KUHNUW' 'omegacsd_LABLOP' 'omegacsd_LACCEX' 'omegacsd_LACPAG'
#  'omegacsd_LADTOZ' 'omegacsd_LANXED' 'omegacsd_LAWJEY' 'omegacsd_LAXWEM'
#  'omegacsd_LEDWAS' 'omegacsd_LEKMET' 'omegacsd_LELROJ' 'omegacsd_LEMXIK'
#  'omegacsd_LERKAU' 'omegacsd_LETBAN' 'omegacsd_LETBUH' 'omegacsd_LEVTOV'
#  'omegacsd_LEZGOM' 'omegacsd_LIKBUC' 'omegacsd_LIKGIV' 'omegacsd_LIKMEX'
#  'omegacsd_LINLAV' 'omegacsd_MAMNAQ' 'omegacsd_MATSTA10'
#  'omegacsd_MBZTZT10' 'omegacsd_MICONZ' 'omegacsd_MINTSA'
#  'omegacsd_MLDPHE10' 'omegacsd_MOPBZA' 'omegacsd_MRMPYR' 'omegacsd_MTBPNP'
#  'omegacsd_MVERIQ' 'omegacsd_NADYIA' 'omegacsd_NADZIB' 'omegacsd_NBPENC'
#  'omegacsd_NFCSEY' 'omegacsd_PACVUK' 'omegacsd_PAPPHI' 'omegacsd_PBBSHD'
#  'omegacsd_PBYXCH' 'omegacsd_PCPTZA' 'omegacsd_PEBHAF' 'omegacsd_PEKCEO'
#  'omegacsd_PEPHEX' 'omegacsd_PEXFED' 'omegacsd_PEXJEH' 'omegacsd_PIBSXM'
#  'omegacsd_PIDSIE' 'omegacsd_PIDWOO' 'omegacsd_PIKDIW' 'omegacsd_PILCOC'
#  'omegacsd_PINSAG' 'omegacsd_PKOJSI' 'omegacsd_PMAANO01' 'omegacsd_PMANAQ'
#  'omegacsd_PMBSAN10' 'omegacsd_PMCPRC10' 'omegacsd_PMEPEN'
#  'omegacsd_PMPAIN' 'omegacsd_PMPBTZ' 'omegacsd_PMTSZD' 'omegacsd_PNBPIP'
#  'omegacsd_PNPAUR' 'omegacsd_PONXUL' 'omegacsd_PTHPAL' 'omegacsd_PXBVCP10'
#  'omegacsd_PXEZSD' 'omegacsd_PXMPEN' 'omegacsd_PYMSBZ' 'omegacsd_QQQHDG10'
#  'omegacsd_SADXIE' 'omegacsd_SAGMUI' 'omegacsd_SAGWOM' 'omegacsd_SAVXOC'
#  'omegacsd_SAVYET' 'omegacsd_SAVZEU' 'omegacsd_SAWZUL' 'omegacsd_SEFLIY'
#  'omegacsd_SEMDET' 'omegacsd_SEMXEN' 'omegacsd_SEYMIS' 'omegacsd_SEYPUH'
#  'omegacsd_SFDMOX' 'omegacsd_SIFJIA' 'omegacsd_SIHDES' 'omegacsd_SIHDIW'
#  'omegacsd_SIHGIZ' 'omegacsd_SIHVUA' 'omegacsd_SILTUC' 'omegacsd_SINKUV'
#  'omegacsd_SISYIC' 'omegacsd_SIZDOU' 'omegacsd_SLFNMB04'
#  'omegacsd_SLFNMF02' 'omegacsd_SOPNAM' 'omegacsd_SOPSIZ' 'omegacsd_SORCOR'
#  'omegacsd_SOWCOW' 'omegacsd_SPIRIL' 'omegacsd_SUKPET' 'omegacsd_SURREC'
#  'omegacsd_TAJSEC' 'omegacsd_TANNOL' 'omegacsd_TAPBZO' 'omegacsd_TAPSOS'
#  'omegacsd_TAPZEP' 'omegacsd_TAZPUF' 'omegacsd_TAZXAT' 'omegacsd_TECSUP'
#  'omegacsd_TEDBUZ' 'omegacsd_TEKBIU' 'omegacsd_TPHPRO' 'omegacsd_VADTAV'
#  'omegacsd_VAMBOA' 'omegacsd_VAMCUH' 'omegacsd_VAYXOI' 'omegacsd_VEMCIZ'
#  'omegacsd_VENRUB' 'omegacsd_VEXROF' 'omegacsd_VEYRAS' 'omegacsd_VIBNID'
#  'omegacsd_VIBWIM' 'omegacsd_VIMYUL' 'omegacsd_VIPHOR' 'omegacsd_VOPDIN'
#  'omegacsd_VORBAF' 'omegacsd_VORDAH' 'omegacsd_VORJER' 'omegacsd_VOWXEK'
#  'omegacsd_VOXHAR' 'omegacsd_VOXMOK' 'omegacsd_VOXNOL' 'omegacsd_VUGDEG'
#  'omegacsd_VURTOR' 'omegacsd_VUSKID' 'omegacsd_WAMZAL' 'omegacsd_WASTEP'
#  'omegacsd_WAVTIW' 'omegacsd_WEBCOV' 'omegacsd_WELGAV' 'omegacsd_WESFOP'
#  'omegacsd_WESZOJ' 'omegacsd_WEVTIA' 'omegacsd_WEXBEG' 'omegacsd_WIDDIW'
#  'omegacsd_WIFREI' 'omegacsd_WIKJOP' 'omegacsd_YABKOB' 'omegacsd_YAGWOS'
#  'omegacsd_YAHBOY' 'omegacsd_YAHFAO' 'omegacsd_YAYDEH' 'omegacsd_YAZBAC'
#  'omegacsd_YAZHUC' 'omegacsd_YEMNEJ' 'omegacsd_YENLEI' 'omegacsd_YESPIV'
#  'omegacsd_YEYVED' 'omegacsd_YICPIJ' 'omegacsd_YIHJAA' 'omegacsd_YILDOM'
#  'omegacsd_YINDII' 'omegacsd_YITLES' 'omegacsd_YOPRAW' 'omegacsd_YOPWOP'
#  'omegacsd_YOSMOI' 'omegacsd_YOWVOV' 'omegacsd_YOWYAK' 'omegacsd_YOXDEU'
#  'omegacsd_YUKKUK' 'omegacsd_YUKNAT' 'omegacsd_YULXIM' 'omegacsd_YULZOU'
#  'omegacsd_YUYJEH' 'omegapdb_1b6l' 'omegapdb_1bhx' 'omegapdb_1bto'
#  'omegapdb_1c1u' 'omegapdb_1d09' 'omegapdb_1d3g' 'omegapdb_1d3h'
#  'omegapdb_1d4i' 'omegapdb_1d4l' 'omegapdb_1d8d' 'omegapdb_1dfo'
#  'omegapdb_1e2m' 'omegapdb_1eby' 'omegapdb_1ec0' 'omegapdb_1exa'
#  'omegapdb_1ezf' 'omegapdb_1f06' 'omegapdb_1f8b' 'omegapdb_1fm9'
#  'omegapdb_1g2k' 'omegapdb_1g4s' 'omegapdb_1g6c' 'omegapdb_1gj6'
#  'omegapdb_1gja' 'omegapdb_1gjd' 'omegapdb_1gs5' 'omegapdb_1gse'
#  'omegapdb_1gz8' 'omegapdb_1h1p' 'omegapdb_1h1s' 'omegapdb_1h2k'
#  'omegapdb_1h6h' 'omegapdb_1hwk' 'omegapdb_1hyo' 'omegapdb_1ik4'
#  'omegapdb_1is0' 'omegapdb_1iy7' 'omegapdb_1j3f' 'omegapdb_1jsl'
#  'omegapdb_1k2t' 'omegapdb_1k2u' 'omegapdb_1koj' 'omegapdb_1kz8'
#  'omegapdb_1l7g' 'omegapdb_1lww' 'omegapdb_1m2x' 'omegapdb_1m5b'
#  'omegapdb_1m5d' 'omegapdb_1m5f' 'omegapdb_1n2b' 'omegapdb_1n3z'
#  'omegapdb_1nms' 'omegapdb_1nnk' 'omegapdb_1nqu' 'omegapdb_1nqv'
#  'omegapdb_1o2q' 'omegapdb_1o2y' 'omegapdb_1o37' 'omegapdb_1o3l'
#  'omegapdb_1o3m' 'omegapdb_1ofd' 'omegapdb_1oiu' 'omegapdb_1oks'
#  'omegapdb_1p1o' 'omegapdb_1pa9' 'omegapdb_1pck' 'omegapdb_1q72'
#  'omegapdb_1q91' 'omegapdb_1qin' 'omegapdb_1qnf' 'omegapdb_1qxw'
#  'omegapdb_1qy5' 'omegapdb_1r34' 'omegapdb_1r4p' 'omegapdb_1r6w'
#  'omegapdb_1rf6' 'omegapdb_1ros' 'omegapdb_1s63' 'omegapdb_1s8j'
#  'omegapdb_1sa4' 'omegapdb_1sn5' 'omegapdb_1syh' 'omegapdb_1t32'
#  'omegapdb_1toj' 'omegapdb_1uf5' 'omegapdb_1uf7' 'omegapdb_1uf8'
#  'omegapdb_1ur8' 'omegapdb_1urw' 'omegapdb_1utt' 'omegapdb_1uu9'
#  'omegapdb_1uwc' 'omegapdb_1uy8' 'omegapdb_1v2k' 'omegapdb_1v2n'
#  'omegapdb_1v97' 'omegapdb_1w1q' 'omegapdb_1w4l' 'omegapdb_1w5v'
#  'omegapdb_1w7x' 'omegapdb_1w9u' 'omegapdb_1wvj' 'omegapdb_1xap'
#  'omegapdb_1xge' 'omegapdb_1xn0' 'omegapdb_1xom' 'omegapdb_1xon'
#  'omegapdb_1xp0' 'omegapdb_1xqc' 'omegapdb_1y6q' 'omegapdb_1yc1'
#  'omegapdb_1yc4' 'omegapdb_1yc5' 'omegapdb_1yvx' 'omegapdb_1z1r'
#  'omegapdb_1zvx' 'omegapdb_1zz2' 'omegapdb_2aj8' 'omegapdb_2aw1'
#  'omegapdb_2ayr' 'omegapdb_2b7d' 'omegapdb_2bgd' 'omegapdb_2brc'
#  'omegapdb_2btr' 'omegapdb_2bts' 'omegapdb_2byh' 'omegapdb_2byi'
#  'omegapdb_2c4w' 'omegapdb_2cbs' 'omegapdb_2cji' 'omegapdb_2evc'
#  'omegapdb_2ewb' 'omegapdb_2f14' 'omegapdb_2f34' 'omegapdb_2f4j'
#  'omegapdb_2f6v' 'omegapdb_2f70' 'omegapdb_2f71' 'omegapdb_2f7p'
#  'omegapdb_2flb' 'omegapdb_2fm0' 'omegapdb_2fqt' 'omegapdb_2fwz'
#  'omegapdb_2fyv' 'omegapdb_2g8n' 'omegapdb_2ggd' 'omegapdb_2gss'
#  'omegapdb_2h03' 'omegapdb_2h42' 'omegapdb_2hb1' 'omegapdb_2hd6'
#  'omegapdb_2i0a' 'omegapdb_2iko' 'omegapdb_2iuz' 'omegapdb_2izl'
#  'omegapdb_2j34' 'omegapdb_2j47' 'omegapdb_2j4i' 'omegapdb_3cbs'
#  'omegapdb_6prc']

# %%
# we're going to loop through method X and method Y
print("Method A, Method B, Mean R2, Median R2, Mean Spearman, Median Spearman, Mean Absolute Energy")
for i in range(len(methods)):
    for j in range(i+1, len(methods)):
        r2 = []
        sp = []
        
        # now we loop through each of the unique molecules
        with open('%s_%s_stats.csv' % (methods[i], methods[j]), 'w') as out:
            print("name, len, rsq, spearman, slope, intercept", sep=',', file=out)
            for name in names:
                x = df[df['name'] == name][methods[i]]
                y = df[df['name'] == name][methods[j]]
                # create a temporary data frame, but drop any 'nan' values
                d = pd.DataFrame({'x': x, 'y': y})
                d.dropna(subset=['y'], inplace = True)
                mask = ~np.isnan(x) & ~np.isnan(y)
                if len(y[mask]) < 3:
                    continue # this molecule has no values (e.g., no DLPNO energies at all)
                    
                spearman = d.corr(method='spearman').values[0, 1]
                slope, intercept, r_value, p_value, std_err = linregress(x[mask], y[mask])
                rsq = r_value**2
                
                # calculate the relative energies
                #minX = 
                
                print(name, len(x), rsq, spearman, slope, intercept, sep=',', file=out)

                if isfinite(rsq):
                    r2.append(rsq)
                if isfinite(spearman):
                    sp.append(spearman)
        # okay, now summarize
        if len(r2) > 0 and len(sp) > 0:
            print(methods[i], methods[j], mean(r2), median(r2), mean(sp), median(sp), sep=', ')
        # instead of just getting mean(r2) or median(spearman)
        # .. generate a histogram from the list of r2 and list of spearman
# Out:
# Method A, Method B, Mean R2, Median R2, Mean Spearman, Median Spearman, Mean Absolute Energy
# mmff, uff, 0.6395337350401585, 0.7414391989559452, 0.6084988220648094, 0.7398333340491294
# mmff, gaff, 0.4166856208624982, 0.37014391756034615, -0.3922690983895583, -0.4800568148193976
# mmff, pm7HOF, 0.4630272023916747, 0.45819894647188486, -0.4846319409826624, -0.5509542924460678
# mmff, ani1x, 0.39259825772151435, 0.3180389796130046, -0.33201262606740584, -0.4146418546569908
# mmff, ani1cc, 0.4032730117886259, 0.3345358851780318, -0.3620461351719351, -0.45454545454545453
# mmff, gfn0, 0.3108587857079591, 0.18609508155912768, -0.048907800483395436, -0.027695578491268365
# mmff, gfn1, 0.29765412741339725, 0.18048378790811925, 0.0049878432058838304, 0.06634984474500864
# mmff, gfn2, 0.2894912666139334, 0.17131085000489366, 0.02328569723359199, 0.11065617431192237
# mmff, pbe, 0.4303822047346006, 0.370594481353568, -0.39840981652679225, -0.5272727272727272
# mmff, pbeSVP, 0.40339639388651966, 0.32763310407143986, -0.32800513799087266, -0.41818181818181815
# mmff, pbeh3c, 0.4380884271726129, 0.4043892472696824, -0.4153874180978318, -0.5151515151515151
# mmff, b3lypTZ, 0.43198633922035196, 0.3732216423493267, -0.4109222446597625, -0.5151515151515151
# mmff, b3lypSVP, 0.4041012063332913, 0.3314986889353935, -0.3398283836942895, -0.41818181818181815
# mmff, wb97, 0.436123007337326, 0.38245323310435764, -0.4275751391465677, -0.5333333333333333
# mmff, mp2, 0.37781832574984564, 0.28058119427415706, -0.3246873321325876, -0.41818181818181815
# mmff, dlpno, 0.4035936039692419, 0.33356051437475864, -0.37480525727278974, -0.47619047619047616
# uff, gaff, 0.43777346354030017, 0.4411316030985902, -0.34176542187608533, -0.4909090909090909
# uff, pm7HOF, 0.3827751676468119, 0.2950888387845563, -0.428426253444992, -0.5439024539830991
# uff, ani1x, 0.4323490051242642, 0.3862774417393639, -0.3486042739569429, -0.46342324932251916
# uff, ani1cc, 0.3939745464191964, 0.327854539567522, -0.3032389590523031, -0.40644850966246954
# uff, gfn0, 0.2584948746459109, 0.13269071295863039, -0.05864728127223821, -0.04520655645367906
# uff, gfn1, 0.2658970299100003, 0.13634897400986035, -0.0008776178060857094, 0.04699164234275773
# uff, gfn2, 0.25710963798145015, 0.13790964038644568, 0.010178048327066506, 0.042300582564432344
# uff, pbe, 0.4255602487554717, 0.35851337983032594, -0.38204821806818956, -0.503030303030303
# uff, pbeSVP, 0.4086001779077814, 0.3348110117986889, -0.3309400300127832, -0.41818181818181815
# uff, pbeh3c, 0.42389108163860045, 0.37970577274014783, -0.38836479735195856, -0.4909090909090909
# uff, b3lypTZ, 0.42872393787067364, 0.37229800024369475, -0.4013573682617905, -0.503030303030303
# uff, b3lypSVP, 0.40874996927110546, 0.3312041698925324, -0.3449966343689596, -0.44242424242424244
# uff, wb97, 0.41787354446610253, 0.3477654508446245, -0.3913840445269017, -0.503030303030303
# uff, mp2, 0.38741225962989534, 0.3199440671115387, -0.3376667614623819, -0.44242424242424244
# uff, dlpno, 0.4017531040108588, 0.34795963082103004, -0.36136691591237047, -0.47878787878787876
# gaff, pm7HOF, 0.3508519902494693, 0.2646825998784475, -0.12030918588648513, -0.17021355223041806
# gaff, ani1x, 0.8213057989380941, 0.9195450183600549, 0.8480192252223088, 0.9329268292682927
# gaff, ani1cc, 0.6863049823599995, 0.7981591877642696, 0.7156264901723983, 0.8427967082225276
# gaff, gfn0, 0.41599282795321, 0.3685060371534711, 0.310926999791073, 0.43161293601284584
# gaff, gfn1, 0.48928355410708635, 0.5117727165381926, 0.43171685451788805, 0.6139845991168652
# gaff, gfn2, 0.47300276604054686, 0.47522907213947707, 0.4213513647524577, 0.5365953413208117
# gaff, pbe, 0.568594825072092, 0.6464011221523532, 0.571835676689269, 0.7113032974423645
# gaff, pbeSVP, 0.5743588255738783, 0.6521006312516804, 0.5633360056303688, 0.7234075969792768
# gaff, pbeh3c, 0.5754092933906236, 0.6443065464931961, 0.5878478601031276, 0.7477238187264794
# gaff, b3lypTZ, 0.5831106107286033, 0.686375014234122, 0.5854458384207029, 0.7212121212121212
# gaff, b3lypSVP, 0.5806632970752212, 0.6698017570192565, 0.5700412225940388, 0.7173285415424762
# gaff, wb97, 0.5779861292899399, 0.6689572713089725, 0.5843671882538976, 0.7408729162393944
# gaff, mp2, 0.5280506065728009, 0.5638455218678441, 0.5080806452968285, 0.6554855993252492
# gaff, dlpno, 0.5443562149637176, 0.594265978925288, 0.5344598110773008, 0.6544332114760286
# pm7HOF, ani1x, 0.36769219315864204, 0.30416804652865853, -0.18368792211656396, -0.24465861447252457
# pm7HOF, ani1cc, 0.3637571310399224, 0.2897329400134999, -0.12782693353039984, -0.18237166310401937
# pm7HOF, gfn0, 0.48535413033962194, 0.48380339550178364, -0.31576685475126154, -0.5270205342925163
# pm7HOF, gfn1, 0.5210417540517024, 0.5621714357208153, -0.4686961425176157, -0.6694920371985105
# pm7HOF, gfn2, 0.5401764806943505, 0.5854005505387975, -0.5039976885587074, -0.7096267904225917
# pm7HOF, pbe, 0.37665901630720505, 0.28590024173986783, -0.23405582288043966, -0.3333333333333333
# pm7HOF, pbeSVP, 0.40998148085364966, 0.34083305567266514, -0.2823425478248808, -0.3696969696969697
# pm7HOF, pbeh3c, 0.3584132519431368, 0.2741186977566728, -0.191847158391556, -0.24848484848484848
# pm7HOF, b3lypTZ, 0.3861279314899159, 0.3165267054928287, -0.25548044134337383, -0.3575757575757576
# pm7HOF, b3lypSVP, 0.41824274828387, 0.3517797851371975, -0.3000722689801148, -0.40606060606060607
# pm7HOF, wb97, 0.3802166521103531, 0.2981576473947878, -0.25139782880648903, -0.34545454545454546
# pm7HOF, mp2, 0.3999362947167771, 0.3429130072344096, -0.2896987973144157, -0.38181818181818183
# pm7HOF, dlpno, 0.3806670931475941, 0.3151445242310368, -0.24367158718271456, -0.3333333333333333
# ani1x, ani1cc, 0.6511743493575332, 0.757599544892258, 0.6485847260491763, 0.7926829268292683
# ani1x, gfn0, 0.4062247097965371, 0.3878370898578302, 0.30358854272718483, 0.3939393939393939
# ani1x, gfn1, 0.47924956198583607, 0.4732494194596388, 0.4408478729024565, 0.5662208585049305
# ani1x, gfn2, 0.4850824144478792, 0.4977211197960974, 0.4604114764901439, 0.5596356443853062
# ani1x, pbe, 0.5710660031576089, 0.6120588482301527, 0.5786890976862311, 0.7073302226501609
# ani1x, pbeSVP, 0.5598750451688486, 0.5886899941133403, 0.5614004385074687, 0.6930123197952736
# ani1x, pbeh3c, 0.5779917264649036, 0.6598628775022279, 0.586729158260419, 0.7294866524160775
# ani1x, b3lypTZ, 0.5861753882516089, 0.6711127582945359, 0.5980212413493868, 0.7333333333333333
# ani1x, b3lypSVP, 0.5670432422951752, 0.6350027392503547, 0.5686314727929198, 0.7090909090909091
# ani1x, wb97, 0.5803488279006206, 0.6851453242963584, 0.5935034778913686, 0.7212121212121212
# ani1x, mp2, 0.5529806275215705, 0.6017411194637481, 0.5447410119457041, 0.6930123197952736
# ani1x, dlpno, 0.5603996042981394, 0.6382779189530505, 0.5572277730509355, 0.713427896983352
# ani1cc, gfn0, 0.42503553176007514, 0.3957809870516065, 0.37357862773816075, 0.5106406566912542
# ani1cc, gfn1, 0.5064417414154694, 0.5243624303695691, 0.45573789257681413, 0.6
# ani1cc, gfn2, 0.490690754784894, 0.5042001558681921, 0.42899480982372706, 0.5592731001856593
# ani1cc, pbe, 0.580476982961554, 0.6695796526438262, 0.5880955850726681, 0.7355657078528781
# ani1cc, pbeSVP, 0.5969445566663514, 0.6822065997272521, 0.5969507293402675, 0.7477238187264794
# ani1cc, pbeh3c, 0.5795142891296637, 0.6635457444371731, 0.5834749113732172, 0.7051704306688749
# ani1cc, b3lypTZ, 0.587077886927808, 0.6798569766616663, 0.5937117040288465, 0.7246315678266502
# ani1cc, b3lypSVP, 0.6026685762211503, 0.6981727578659901, 0.5970504184465693, 0.7538028741632801
# ani1cc, wb97, 0.5804321278342128, 0.6769485989926298, 0.5867903346276905, 0.7234075969792768
# ani1cc, mp2, 0.5318757490332823, 0.5963529751270389, 0.512853718948215, 0.6606060606060606
# ani1cc, dlpno, 0.5477821921580106, 0.6326120254709451, 0.5483039749118511, 0.6898942699802268
# gfn0, gfn1, 0.7072763899555886, 0.8317458092935859, 0.7572501696716507, 0.8607267601257715
# gfn0, gfn2, 0.6808774981276448, 0.7989742012431098, 0.7125082180969339, 0.8329175549828919
# gfn0, pbe, 0.48046494413794516, 0.484567605986152, 0.4763557979476033, 0.6121212121212121
# gfn0, pbeSVP, 0.5475412491113865, 0.6165572974653918, 0.5661171047338929, 0.7212121212121212
# gfn0, pbeh3c, 0.4266205489047499, 0.39883691261677356, 0.36765781047698176, 0.47878787878787876
# gfn0, b3lypTZ, 0.4707210402199381, 0.46221679225770007, 0.4723026788099226, 0.6121212121212121
# gfn0, b3lypSVP, 0.5319582637240335, 0.5913466949663732, 0.5507116582176664, 0.696969696969697
# gfn0, wb97, 0.4389384079471013, 0.396635855491813, 0.415493054682869, 0.5393939393939394
# gfn0, mp2, 0.4505731297663981, 0.4566867485668488, 0.4267413229053846, 0.5636363636363636
# gfn0, dlpno, 0.4317987792922554, 0.40462363629073966, 0.3935262637602521, 0.5272727272727272
# gfn1, gfn2, 0.8590466212206294, 0.9311154544919895, 0.8499853406410971, 0.9187128878557987
# gfn1, pbe, 0.6233202689404725, 0.7071404031564813, 0.6402381458698285, 0.7744046403152623
# gfn1, pbeSVP, 0.6771699538595033, 0.7790226034082103, 0.6969792170252256, 0.8181818181818182
# gfn1, pbeh3c, 0.5564210466056041, 0.607957164466373, 0.5654317992017306, 0.7212121212121212
# gfn1, b3lypTZ, 0.6216538566272062, 0.7122806963840578, 0.6424698394682059, 0.772040040473682
# gfn1, b3lypSVP, 0.675690015532374, 0.7799632864127821, 0.6977549650489967, 0.8109906863144086
# gfn1, wb97, 0.5832520825636824, 0.6576246530483452, 0.59764605654528, 0.7435496543721121
# gfn1, mp2, 0.590082496418428, 0.6778874837758578, 0.5911377493819298, 0.7212121212121212
# gfn1, dlpno, 0.5625612967675824, 0.6223859859048215, 0.5666157411425313, 0.696969696969697
# gfn2, pbe, 0.6605479599313817, 0.7824470028228618, 0.6897861029441267, 0.8181818181818182
# gfn2, pbeSVP, 0.6883137410249841, 0.798941400257551, 0.7170527147200939, 0.8303030303030303
# gfn2, pbeh3c, 0.5905003954820389, 0.6723621393894474, 0.6134133059551022, 0.754658036542014
# gfn2, b3lypTZ, 0.6557082678046994, 0.7700844685769876, 0.6861923277204403, 0.8109906863144086
# gfn2, b3lypSVP, 0.6787922028612682, 0.7923156584451881, 0.7077619775141147, 0.8328305948416884
# gfn2, wb97, 0.6135046799557634, 0.6999392586631483, 0.6354735748563375, 0.7696969696969697
# gfn2, mp2, 0.5999705293924185, 0.6712509975596604, 0.6093423994884043, 0.7212121212121212
# gfn2, dlpno, 0.5752542651322753, 0.6371367807107677, 0.5854381190371096, 0.7173285415424762
# pbe, pbeSVP, 0.896951796585463, 0.9657823911701777, 0.9066460405975385, 0.9636363636363636
# pbe, pbeh3c, 0.8437762918585604, 0.9212803665800443, 0.8553386936411188, 0.9272727272727272
# pbe, b3lypTZ, 0.962134123228521, 0.9871268025875707, 0.9577820182670397, 0.9757575757575757
# pbe, b3lypSVP, 0.8674289849120723, 0.9480254333974613, 0.8831860483786305, 0.9515151515151515
# pbe, wb97, 0.9156726503646709, 0.9701681378850879, 0.9146836734693877, 0.9515151515151515
# pbe, mp2, 0.7611837873686881, 0.8669717136016828, 0.7907018042784466, 0.8909090909090909
# pbe, dlpno, 0.7846109863273356, 0.8846795260465726, 0.8019002642379266, 0.8909090909090909
# pbeSVP, pbeh3c, 0.7671575830761831, 0.8746647437053572, 0.7921469638302734, 0.8909090909090909
# pbeSVP, b3lypTZ, 0.8720317727025451, 0.9480578120301433, 0.8843488893417567, 0.9393939393939394
# pbeSVP, b3lypSVP, 0.9571956512081983, 0.9849769150765293, 0.9499471997332197, 0.9757575757575757
# pbeSVP, wb97, 0.81366445202899, 0.9108876381858189, 0.8326991341991342, 0.9151515151515152
# pbeSVP, mp2, 0.741889181686461, 0.843324256563786, 0.762664391569501, 0.8666666666666667
# pbeSVP, dlpno, 0.7375454818314863, 0.8348644337928337, 0.7524684070138615, 0.8545454545454545
# pbeh3c, b3lypTZ, 0.8749465899365192, 0.9436166804274327, 0.8818487503936862, 0.9393939393939394
# pbeh3c, b3lypSVP, 0.7904015219096541, 0.88740159010278, 0.8160095966800675, 0.9030303030303031
# pbeh3c, wb97, 0.8907046612535547, 0.9468016907178899, 0.8941246134817563, 0.9393939393939394
# pbeh3c, mp2, 0.7435470004212638, 0.8466226834962454, 0.7686605365437482, 0.8666666666666667
# pbeh3c, dlpno, 0.7814625045386772, 0.8792869235923223, 0.8011837609240207, 0.8787878787878788
# b3lypTZ, b3lypSVP, 0.8818378358059373, 0.953719152743048, 0.8929414380198973, 0.9428571428571428
# b3lypTZ, wb97, 0.9629301117152369, 0.9902153115785014, 0.9556536796536796, 0.9757575757575757
# b3lypTZ, mp2, 0.8040358360965177, 0.9058308498360451, 0.8259462192308907, 0.9030303030303031
# b3lypTZ, dlpno, 0.8309662475221151, 0.9200578018648526, 0.8395073180787467, 0.9151515151515152
# b3lypSVP, wb97, 0.8314989080306349, 0.9241800419215096, 0.8524545454545455, 0.9272727272727272
# b3lypSVP, mp2, 0.7841299186593714, 0.8814994688772324, 0.7977132113628465, 0.8909090909090909
# b3lypSVP, dlpno, 0.7742721282876877, 0.8680160792816481, 0.7860006996370633, 0.8787878787878788
# wb97, mp2, 0.7970600153462328, 0.9001748731972706, 0.8166717298296245, 0.9030303030303031
# wb97, dlpno, 0.8338442906670475, 0.9289869373542906, 0.8426281810674874, 0.9151515151515152
# mp2, dlpno, 0.9136820313158717, 0.963911229103808, 0.9164562554430395, 0.9515151515151515

# %%
print(len(r2), r2)
